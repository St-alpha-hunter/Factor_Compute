# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

project_path = r"D:\YanFeng\Project"
if project_path not in sys.path:
    sys.path.append(project_path)


from src.data_load import get_all_stock_codes, get_stock_codes_by_exchange, load_data, load_multiple_stocks
from src.factor_cal import StockFactorCalculator

# %%
df = load_data(r'D:\YanFeng\Project\data_set\000001.SZ\逐笔成交.csv')
df_01 = load_data(r'D:\YanFeng\Project\data_set\600006.SH\逐笔成交.csv')
# Out:
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000001.SZ\逐笔成交.csv
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\600006.SH\逐笔成交.csv

# %%
print('深圳股市',df["成交代码"].value_counts(dropna=False).head(10))
print('上海股市',df_01["成交代码"].value_counts(dropna=False).head(10))
# Out:
# 深圳股市 成交代码
# 0    45416
# C    23470
# Name: count, dtype: int64
# 上海股市 成交代码
# NaN    13223
# Name: count, dtype: int64

# %%
print('上海股市',df_01["成交代码"].unique())
print('深圳股市',df["成交代码"].unique())
# Out:
# 上海股市 [nan]
# 深圳股市 ['C' '0']
