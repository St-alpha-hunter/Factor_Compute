# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
project_path = r"D:\YanFeng\Project"
if project_path not in sys.path:
    sys.path.append(project_path)

# %%
from src.data_load import get_all_stock_codes, get_stock_codes_by_exchange
from src.factor_cal import cal_volume_ratio, cal_act_ratio, cal_order_ratio

# %%
cal_volume_ratio(['000001.SZ', '000002.SZ'])
cal_act_ratio(['000001.SZ', '000002.SZ'])
cal_order_ratio(['000001.SZ', '000002.SZ'])
# Out:
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000001.SZ\逐笔成交.csv
# 股票 000001.SZ 下午成交量与上午成交量的比率为: 1.8542
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000002.SZ\逐笔成交.csv
# 股票 000002.SZ 下午成交量与上午成交量的比率为: 3.6756
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000001.SZ\逐笔成交.csv
# 000001.SZ ACT=-0.3667, X_ACT=-0.3667, L_ACT=-1.0000
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000002.SZ\逐笔成交.csv
# 000002.SZ ACT=-0.3988, X_ACT=-0.3988, L_ACT=-0.9612, M_ACT=-1.0000
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000001.SZ\逐笔委托.csv
# 000001.SZ 委托量比率 Buy=16899551060000.00, Sell=15946874415000.00, X_ACT=0.0290, S_ACT=0.0000, L_ACT=-1.0000
# 成功使用 gbk 编码读取文件: D:\YanFeng\Project\data_set\000002.SZ\逐笔委托.csv
# 000002.SZ 委托量比率 Buy=17218357130000.00, Sell=19978989191500.00, X_ACT=-0.0742, S_ACT=0.0000, L_ACT=-1.0000
